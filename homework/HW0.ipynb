# %% [markdown]
# # Homework 0 Set up Python Jupyter notebook
# If you have successfully installed python in your PC or laptop, please follow the instruction and finish your very first homework.

# %% [markdown]
#  - Download the notebook template
#  - Execute the following code
#  - Save the file which shows the results
#  - Upload the file to Blackboard
#  - Congrats!

# %%
import numpy as np

# %%
print('Hello Statistics and Machine Learning')
# Out:
# Hello Statistics and Machine Learning

# %%
# print your name here

# %%
point = np.ones((2,2))
print(point)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
# for data generated by numpy, one can use .shape to know the information of # of rows and columns

point.shape
# Out:
# (2, 2)

# %%
# operator // is the floor division

7//3
# Out:
# 2

# %%
# operator % is to find the remainder of division

7%3
# Out:
# 1

# %%
# @ operator can be the inner product between two vector

np.array([1,2,3]) @ np.array([1,2,3])

# answer is 1*1 + 2*2 + 3*3
# Out:
# 14

# %%
# @ operator can be multiplication of matrix

a = np.random.rand(2,4)
b = np.random.rand(2,3)
a@b

# a pair of matrices must have matched dimension to proceed multiplication, otherwise error message shows up
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d987d8fa89a2> in <module>
#       3 a = np.random.rand(2,4)
#       4 b = np.random.rand(2,3)
# ----> 5 a@b
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 4)

# %%
a = np.random.rand(3,5)
b = np.random.rand(5,2)
a@b
# Out:
# array([[1.26126332, 0.7868528 ],
#        [1.34123819, 0.71161494],
#        [1.63821502, 1.09369134]])

# %%
# 2 to the power of 5 in binary form is shifted to the right by 3

32>>3
# Out:
# 4

# %%
# what do you expect from the following operation?

2 << 4

# %%
import random

# %%
rnd1 = random.uniform(1,2)
rnd1
# Out:
# 1.0809768877360142

# %%
rnd2 = random.uniform(0,1)
rnd1 + rnd2
